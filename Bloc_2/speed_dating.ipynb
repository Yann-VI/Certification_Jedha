# %% [markdown]
# ### Import Dataset

# %%
# %matplotlib inline
import pandas as pd
pd.options.display.max_rows = 1000 #handy for showing truncated results
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn import metrics

# %%
speed_dating = pd.read_csv('Speed+Dating+Data.csv', encoding='ISO-8859-1')
speed_dating.head()
# Out:
#    iid   id  gender  idg  condtn  wave  round  position  positin1  order  ...  \
# 0    1  1.0       0    1       1     1     10         7       NaN      4  ...
# 1    1  1.0       0    1       1     1     10         7       NaN      3  ...
# 2    1  1.0       0    1       1     1     10         7       NaN     10  ...
# 3    1  1.0       0    1       1     1     10         7       NaN      5  ...
# 4    1  1.0       0    1       1     1     10         7       NaN      7  ...
#
#    attr3_3  sinc3_3  intel3_3  fun3_3  amb3_3  attr5_3  sinc5_3  intel5_3  \
# 0      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
# 1      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
# 2      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
# 3      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
# 4      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
#
#    fun5_3  amb5_3
# 0     NaN     NaN
# ...

# %%
speed_dating.isna().sum().sort_values(ascending=False)
# Out:
# num_in_3    7710
# numdat_3    6882
# expnum      6578
# sinc7_2     6423
# amb7_2      6423
# shar7_2     6404
# attr7_2     6394
# intel7_2    6394
# fun7_2      6394
# amb5_3      6362
# attr7_3     6362
# sinc7_3     6362
# intel7_3    6362
# fun7_3      6362
# amb7_3      6362
# shar7_3     6362
# shar2_3     6362
# attr5_3     6362
# sinc5_3     6362
# intel5_3    6362
# fun5_3      6362
# attr4_3     5419
# sinc4_3     5419
# intel4_3    5419
# fun4_3      5419
# amb4_3      5419
# shar4_3     5419
# attr2_3     5419
# sinc2_3     5419
# fun2_3      5419
# intel2_3    5419
# amb2_3      5419
# mn_sat      5245
# tuition     4795
# you_call    4404
# shar1_3     4404
# date_3      4404
# attr1_3     4404
# sinc1_3     4404
# intel1_3    4404
# fun1_3      4404
# amb1_3      4404
# attr3_3     4404
# sinc3_3     4404
# intel3_3    4404
# fun3_3      4404
# amb3_3      4404
# them_cal    4404
# fun3_s      4378
# intel3_s    4378
# sinc3_s     4378
# amb3_s      4378
# ...

# %%
speed_dating.isnull().sum()
# Out:
# iid            0
# id             1
# gender         0
# idg            0
# condtn         0
# wave           0
# round          0
# position       0
# positin1    1846
# order          0
# partner        0
# pid           10
# match          0
# int_corr     158
# samerace       0
# age_o        104
# race_o        73
# pf_o_att      89
# pf_o_sin      89
# pf_o_int      89
# pf_o_fun      98
# pf_o_amb     107
# pf_o_sha     129
# dec_o          0
# attr_o       212
# sinc_o       287
# intel_o      306
# fun_o        360
# amb_o        722
# shar_o      1076
# like_o       250
# prob_o       318
# met_o        385
# age           95
# field         63
# field_cd      82
# undergra    3464
# mn_sat      5245
# tuition     4795
# race          63
# imprace       79
# imprelig      79
# from          79
# zipcode     1064
# income      4099
# goal          79
# date          97
# go_out        79
# career        89
# career_c     138
# sports        79
# tvsports      79
# ...

# %%
# age distribution of participants
age = speed_dating[np.isfinite(speed_dating['age'])]['age']
plt.hist(age.values)
plt.xlabel('Age')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')
